# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.multiclass import OneVsRestClassifier

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# ----- Csv files and paths used to classify music ----
TRAIN_PATH = '../input/tsma-202223-music-genre-classification/train/Train/'
TEST_PATH = '../input/tsma-202223-music-genre-classification/test/Test/'
test_files_csv = pd.read_csv("../input/tsma-202223-music-genre-classification/test/.csv" , header=0)
test = pd.read_csv('../input/tsma-202223-music-genre-classification/test.csv', header=0)
train = pd.read_csv('../input/tsma-202223-music-genre-classification/train.csv', header=0)
genres = pd.read_csv('../input/tsma-202223-music-genre-classification/genres.csv', header=0)

# %%
#os.remove("/kaggle/working/train_mfcc.txt")
#os.remove("/kaggle/working/test_mfcc.txt")
import librosa
# ---- text files saved to avoid extracting mfcc again
train_mfcc = np.empty((train.size, 1291)) * np.nan
test_mfcc = np.empty((test.size, 1291)) * np.nan
if(os.path.isfile("/kaggle/working/train_mfcc.txt")):
    train_mfcc = np.loadtxt("/kaggle/working/train_mfcc.txt", dtype=np.float32)
if(os.path.isfile("/kaggle/working/test_mfcc.txt")):
    test_mfcc = np.loadtxt("/kaggle/working/test_mfcc.txt", dtype=np.float32)

print("size of train: " + str(train.size))
print("size of test: " + str(test.size))

# --- if there are txt saved, we populate train x and test x ----
if(np.isnan(train_mfcc[0][0])):
    X_train = np.empty((train.size, 1291)) * np.nan
    size = 0
    for row in train.itertuples():
        idx = f'{row.track_id:06d}'
        audio, sr = librosa.load(TRAIN_PATH + idx + ".mp3" )
        x_i = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=1)
        if(x_i.shape[1] > 1291):
            x_i = x_i[:, :1291]
        X_train[size] = x_i
        size+=1
        
np.savetxt('train_mfcc.txt', X_train)

print(X_train.shape)
print(y_train)

if(np.isnan(test_mfcc[0][0])):
    X_test = np.empty((test.size, 1291)) * np.nan
    size = 0
    for row in test_files_csv.itertuples():
        idx = f'{row.track_id:06d}'
        audio, sr = librosa.load(TEST_PATH + idx + ".mp3")
        x_i = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=1)
        if(x_i.shape[1] > 1291):
            x_i = x_i[:, :1291]
        X_test[size] = x_i
        size+=1

np.savetxt('test_mfcc.txt', X_test)        

y_train = train["genre_id"].tolist()
y_train = y_train[:10]

knn = OneVsRestClassifier(KNeighborsClassifier())
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(y_pred)

test.to_csv("submission.csv", encoding='utf-8', index=False)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# size of train: 8000
# size of test: 4008
# /opt/conda/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /opt/conda/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /opt/conda/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /opt/conda/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /opt/conda/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /opt/conda/lib/python3.7/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
# ...

# %%
#import os
#for dirname, _, filenames in os.walk('/kaggle/working'):
 #   for filename in filenames:
  #     os.remove(os.path.join(dirname, filename))
